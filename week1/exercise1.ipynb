# %% [markdown]
# ## Your first Jupyter Notebook
#
# This is a Jupiter notebook. This will be our main format for most of the exercise sessions in this class.
#
# The cool thing about Jupyter notebook is that it combines code and explanations in one file and let you run Python code directly from here.
#
# In Jupyter notebook, we have two types of cells: text cells, which allow you to write and render text in Markdown syntax (What you are reading now is in a text cell), and code cells, which allow you to write and run Python code.
#
#
# First, let's try to run the following code cell by clicking on the button next to it:

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# You can always play around and edit the code cell to try your own code. However, there are certain syntax rules that we always need to follow in programming. Otherwise, we will get syntax errors. Can you identify the issue in the code below and fix it?

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# You should always close the parentheses, or you will see another error message:

# %%
print("Forgetful parentheses"
# Add the right parenthesis back to get rid of the annoying red error lines after this cell in PyCharm
# Out:
# Forgetful parentheses

# %%
print('Single quotation marks work as well')
# Out:
# Single quotation marks work as well

# %% [markdown]
# You can also print multiple lines by repeating the print command:

# %%
print("Welcome to Technical Basics I!")
print("This is our first class of the semester.")
print("Let's learn the print function in Python.")
# Out:
# Welcome to Technical Basics I!
# This is our first class of the semester.
# Let's learn the print function in Python.

# %% [markdown]
# Or use triple quotes to print a multi-line string:

# %%
print("""
Welcome to Technical Basics I
This is our first class of the semester
Let's learn the print command in Python
""")
# Out:
# Welcome to Technical Basics I
# This is our first class of the semester
# Let's learn the print command in Python

# %% [markdown]
# ##### Task 1
# Now it's your turn. Try to create a new code block below and print an emoticon of your choice :-)

# %% [markdown]
# ---

# %% [markdown]
# You can print arithmetic operations directly:

# %%
print(3+4)
print(11*13)
print(8*5+4)
# Out:
# 7
# 143
# 44

# %% [markdown]
# Notice that there is no quotation marks around the arithmetic operations. Quotation marks are used to signify <i>strings</i>. We will talk more about strings next week. For now, what you put between the quotation marks will be printed exactly as it is.
# Notice the differences between the following two lines of code

# %%
print(1+2-3)
print("1+2-3")
# Out:
# 0
# 1+2-3

# %% [markdown]
# You can even combine the two styles together, but don't forget to separate them with a comma.

# %%
print("This is the result of 2025+2024:", 2025+2024)
# Out:
# This is the result of 2025+2024: 4049

# %% [markdown]
# And more commas

# %%
print("One hour has ", 60*60, "seconds. One day has ", 60*60*24, "minutes.")
# Out:
# One hour has  3600 seconds. One day has  86400 minutes.

# %% [markdown]
# Notice that all characters have the same width in your output

# %%
print("-----")
print("wwwww")
print("+++++")
# Out:
# -----
# wwwww
# +++++

# %% [markdown]
# ##### Task 2
# Use print with arithmetic operations to calculate how many days have passed in 2026.

# %%
print (3*30+14, "days have passed")
# Out:
# 104 days have passed

# %% [markdown]
# ---
# ### Commenting
#
# Any line beginning with `#`, the pound sign, are not treated as code. They are messages for human readers and Python will simply ignore it.
#
# Comments are used for explaining how a program works, to both the programmer themselves, and others reading the program code.
#
# In the code cell below, the comment explains the calculation performed in the code:

# %%
print("Number of students registered in Tech Basics I:")
# there are in total 2 sessions of Tech Basics I and each has 21 students
print(2*21)
# Out:
# Number of students registered in Tech Basics I:
# 42

# %% [markdown]
# `#` only works for a single line of comment. If you have more to write, you can use triple quotes `'''` instead.

# %%
'''
This is an example of a multi-line comment.
You can write as much text as you want between the triple quotes without worrying about line breaks.
'''

print("This is the only message that is being printed")
# Out:
# This is the only message that is being printed

# %% [markdown]
# ---
# ### Task 3 - Assignment

# %% [markdown]
# - Make a little piece of ASCII art with print functions in python.
# - Comment your code with your thought process and any resources that you used for this exercise
# - You can first try it out here in the notebook. After you are satisfied with your result, save it as a `.py` file. (not as `.ipynb`!!!)

# %%
'''
This code prints a simple ASCII art tennis ball.
I used the letter O for the ball shape.
I used simple shapes to keep it readable.
'''

print("   OOOOO   ")

print(" OO     OO ")

print("O         O")

print("O         O")

print(" OO     OO ")

print("   OOOOO   ")
# Out:
#    OOOOO
#  OO     OO
# O         O
# O         O
#  OO     OO
#    OOOOO
